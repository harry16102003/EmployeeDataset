# %% [markdown]
# # Employee_Dataset

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Employee.csv')
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
df.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
print(df.isnull().sum())
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1889

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (2764, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2764 entries, 0 to 4651
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  2764 non-null   object
#  1   JoiningYear                2764 non-null   int64
#  2   City                       2764 non-null   object
#  3   PaymentTier                2764 non-null   int64
#  4   Age                        2764 non-null   int64
#  5   Gender                     2764 non-null   object
#  6   EverBenched                2764 non-null   object
#  7   ExperienceInCurrentDomain  2764 non-null   int64
#  8   LeaveOrNot                 2764 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 215.9+ KB

# %%
df.columns
# Out:
# Index(['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender',
#        'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot'],
#       dtype='object')

# %%
df.Education.value_counts()
# Out:
# Education
# Bachelors    1971
# Masters       637
# PHD           156
# Name: count, dtype: int64

# %%
edu_count = df.Education.value_counts()
plt.figure(figsize=(4,4))
plt.pie(edu_count, labels=edu_count.index, autopct='%1.1f%%', startangle=80)
plt.title('Pie Chart of Employees Education')
plt.show()

# %% [markdown]
# * PhD: 5.6% of employees hold a PhD.
# * Masters: 23.0% of employees have a Master's degree.
# * Bachelors: 71.3% of employees hold a Bachelor's degree.<br>
# <b>This indicates that the majority of employees have a Bachelor's degree, followed by a smaller percentage with Master's degrees, and the smallest percentage with PhDs.

# %%
df.JoiningYear.value_counts()
# Out:
# JoiningYear
# 2017    662
# 2015    464
# 2013    396
# 2014    385
# 2016    310
# 2012    308
# 2018    239
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,4))
sns.countplot(data=df,x='JoiningYear')
# Out:
# <Axes: xlabel='JoiningYear', ylabel='count'>

# %% [markdown]
# * 2012: Approximately 100 individuals.
# * 2013: Around 200 individuals.
# * 2014: Close to 300 individuals.
# * 2015: Approximately 400 individuals.
# * 2016: Around 500 individuals.
# * 2017: Close to 600 individuals.
# * 2018: Approximately 600 individuals.<br>
#
# <b>There's consistent growth in the number of employees joining each year, with the growth rate slowing down or plateauing in the later years.

# %%
pd.crosstab(df.JoiningYear,df.City,values=df.Age,aggfunc='median')
# Out:
# City            0     1     2
# JoiningYear
# 2012         31.0  28.0  29.0
# 2013         30.0  28.0  29.0
# 2014         31.0  28.0  30.0
# 2015         31.0  28.0  30.0
# 2016         31.0  28.0  29.0
# 2017         30.0  30.0  30.0
# 2018         31.0  29.0  29.0

# %%
city_joinyear= df.groupby(['JoiningYear', 'City']).size().unstack()
ax = city_joinyear.plot(kind='bar', stacked=True, figsize=(8, 6))
plt.xlabel('Joining Year')
plt.ylabel('Number of Employees')
plt.title('Distribution of Employees by Joining Year and City')
plt.legend(title='City', loc='upper left')
plt.show()

# %% [markdown]
# * Cities: The data includes employees from three cities: Bangalore, New Delhi, and Pune.
# * Joining Years: The distribution covers employees who joined from 2013 to 2021.
# * Number of Employees: The number of employees varies each year across the cities. The data points suggest fluctuations in employee numbers over the years.<br>
#
# <b>This data provides insights into the geographic and temporal distribution of employees, highlighting potential patterns in hiring and workforce expansion across different cities and years.

# %%
pd.crosstab(df.Gender,df.Education)
# Out:
# Education  Bachelors  Masters  PHD
# Gender
# Female           894      278   63
# Male            1077      359   93

# %%
plt.figure(figsize=(4,4))
sns.countplot(data=df,x='Education',hue='Gender')
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %% [markdown]
# * Gender Categories: The data includes two gender categories: Male and Female.
# * Education Levels: The education levels considered are Bachelors, Masters, and PhD.
# * Data Structure: The image suggests a comparison or distribution of gender across different education levels.
# * Potential Analysis: The data could be used to analyze the representation of males and females at each education level within a specific context, such as a company or academic institution.<br>
#
# <b>It indicates that the image is likely part of a broader analysis of gender distribution across various educational qualifications.

# %%
pd.crosstab(df.PaymentTier,df.Gender)
# Out:
# Gender       Female  Male
# PaymentTier
# 1               115   103
# 2               367   203
# 3               753  1223

# %%
plt.figure(figsize=(4,4))
sns.countplot(data=df,x='PaymentTier',hue='Gender')
# Out:
# <Axes: xlabel='PaymentTier', ylabel='count'>

# %% [markdown]
# * Gender Categories: The data includes two gender categories: Female and Male.
# * Payment Tiers: There are three payment tiers (1, 2, and 3) represented on the x-axis.
# * Count of Employees: The y-axis shows the count of employees, ranging from 0 to 1200.
# * Distribution:<br>
# 1.The count of employees varies across different payment tiers for both genders.<br>
# 2.The highest count appears to be in Payment Tier 1, with a significant number of both female and male employees.<br>
# 3.The counts decrease in Payment Tiers 2 and 3, with fewer employees in these categories.<br>
#
# <b>This data provides insights into the distribution of employees across different payment tiers, segmented by gender. It highlights potential disparities or trends in compensation levels between male and female employees.

# %%
x=pd.crosstab([df.Gender,df.PaymentTier],df.JoiningYear)
plt.figure(figsize=(8, 6))
sns.heatmap(x, annot=True, fmt='d', cmap='YlGnBu')
plt.xlabel('Joining Year')
plt.ylabel('Gender and Payment Tier')
plt.title('Crosstab: Gender and Payment Tier vs. Joining Year')
plt.show()

# %% [markdown]
# * Gender Disparity:<br>
# Male employees significantly outnumber female employees across all payment tiers, particularly in higher tiers (Tier 3). This indicates a potential gender disparity in higher-paying roles.
# * Payment Tier Distribution:<br>
# Male-1 and Male-3 show the highest counts, suggesting that male employees are more prevalent in both lower and higher payment tiers.
# Female-2 and Female-3 have lower counts, indicating fewer female employees in these categories.<br>
# * Joining Year Trends:<br>
# The year 2017 stands out with the highest number of employees across most categories, suggesting a peak in hiring or retention during that year.<br>
# There is a general trend of increasing employee counts from 2012 to 2017, followed by a slight decline in 2018.

# %%
df.EverBenched.value_counts()
# Out:
# EverBenched
# No     2403
# Yes     361
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,4))
sns.countplot(data=df,x='EverBenched',hue='Gender')
# Out:
# <Axes: xlabel='EverBenched', ylabel='count'>

# %% [markdown]
# * Gender Distribution: More male employees than female employees.
# * Bench Status:
# Higher number of males both benched ("Yes") and not benched ("No").<br>
# Fewer females in both categories compared to males.<br>
# * Trend: Males are more likely to be benched than females.
# * Implication: Potential gender disparity in project assignments or workforce utilization.

# %%
x = pd.crosstab([df['Gender'], df['Education']], df['EverBenched'])
plt.figure(figsize=(12, 8))
x.plot(kind='bar', stacked=True)
plt.title('Stacked Bar Plot of Gender, Education, and EverBenched')
plt.xlabel('Gender, Education')
plt.ylabel('Count')
plt.show()

# %%
pd.crosstab(df.ExperienceInCurrentDomain,df.Gender)
# Out:
# Gender                     Female  Male
# ExperienceInCurrentDomain
# 0                             119   168
# 1                             192   241
# 2                             302   379
# 3                             202   249
# 4                             204   221
# 5                             210   260
# 6                               2     6
# 7                               4     5

# %%
sns.countplot(data=df,x='ExperienceInCurrentDomain',hue='Gender')
plt.title('Stacked Bar Plot of Experience In Current Domain')
# Out:
# Text(0.5, 1.0, 'Stacked Bar Plot of Experience In Current Domain')

# %%
pd.crosstab(df.ExperienceInCurrentDomain,df.PaymentTier)
# Out:
# PaymentTier                 1    2    3
# ExperienceInCurrentDomain
# 0                          23   56  208
# 1                          35   75  323
# 2                          48  167  466
# 3                          37   92  322
# 4                          32   91  302
# 5                          41   87  342
# 6                           1    1    6
# 7                           1    1    7

# %%
df.ExperienceInCurrentDomain.value_counts()
# Out:
# ExperienceInCurrentDomain
# 2    681
# 5    470
# 3    451
# 1    433
# 4    425
# 0    287
# 7      9
# 6      8
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x='ExperienceInCurrentDomain',hue='PaymentTier')
plt.title('Stacked Bar Plot of ExperienceInCurrentDomain with PaymentTier')
plt.show()

# %%
x=pd.crosstab([df.Gender,df.EverBenched],df.LeaveOrNot)
x
# Out:
# LeaveOrNot            0    1
# Gender EverBenched
# Female No           558  540
#        Yes           63   74
# Male   No           916  389
#        Yes          139   85

# %%
x.plot(kind='bar',stacked=True)
plt.title('Stacked Bar Plot of Gender, EverBenched, and LeaveOrNot')
plt.xlabel('(Gender, EverBenched)')
plt.ylabel('Count')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split 
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
le=LabelEncoder()
df["Education"]=le.fit_transform(df["Education"])
df["City"]=le.fit_transform(df["City"])
df["Gender"]=le.fit_transform(df["Gender"])
df["EverBenched"]=le.fit_transform(df["EverBenched"])
df.head()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15748\2417979659.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Education"]=le.fit_transform(df["Education"])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15748\2417979659.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["City"]=le.fit_transform(df["City"])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15748\2417979659.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
x=df.drop(columns='LeaveOrNot')
y=df.LeaveOrNot
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.25)

# %%
model_svm = SVC(kernel = 'linear', random_state = 0)
print(model_svm.fit(X_train, y_train))
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred = model_svm.predict(X_test)

# %%
conf_matrix_svm = confusion_matrix(y_test, y_pred)
print(conf_matrix_svm)
# Out:
# [[354  78]
#  [139 120]]

# %%
accuracy_svm = accuracy_score(y_test, y_pred)
print(accuracy_svm)
# Out:
# 0.6859623733719248

# %%
classification_rep_svm = classification_report(y_test, y_pred)
print(classification_rep_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.82      0.77       432
#            1       0.61      0.46      0.53       259
#
#     accuracy                           0.69       691
#    macro avg       0.66      0.64      0.65       691
# weighted avg       0.68      0.69      0.68       691
